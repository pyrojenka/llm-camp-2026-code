# %%
from rag_helper import RAGBase

# %%
import os
from ingest import load_faq_data, build_index
from google import genai
from dotenv import load_dotenv
load_dotenv()

client = genai.Client(api_key=os.getenv('GEMINI_API_KEY'))

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, client)

# %%
print(index.search('help'))
# Out:
# [{'id': '1f17886bde', 'course': 'machine-learning-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'How do I get help if I’m stuck?', 'answer': '- [Slack](https://datatalks.club/slack.html): paste your code and errors, and use threads to keep discussions organized.\n- this FAQ and [past office hours](https://www.youtube.com/@DataTalksClub/search?query=ml%20zoomcamp%20office%20hours): check these resources for guidance before asking.\n- AI assistants like ChatGPT: use them for quick guidance or brainstorming.\n- Peers and instructors: they may chime in when available.'}, {'id': '62f5aa4d83', 'course': 'machine-learning-zoomcamp', 'section': 'General Course-Related Questions', 'question': 'Can this program help data engineers move into DS/ML engineering?', 'answer': 'Yes. The program’s project-first flow, deployment modules (FastAPI/Lambda/Kubernetes), and evaluation practices map well to ML engineer roles. Practically, you’ll gain experience with end-to-end ML workflows—from data engineering pipelines and model deployment to evaluation and monitoring—using tools commonly used in DS/ML roles.'}, {'id': '1a96e5837b', 'course': 'machine-learning-zoomcamp', 'section': 'Module 3 Homework', 'question': 'Homework: I am getting 1.0 as accuracy. Should I use the closest option?', 'answer': 'If you are getting 1.0 as accuracy, it is possible that you have overfitted the model. Dropping the column `msrp/price` can help you solve this issue.'}, {'id': 'a83f047f52', 'course': 'data-engineering-zoomcamp', 'section': 'Environment & Setup', 'question': 'How to troubleshoot issues and ask good questions', 'answer': "**Try to solve it yourself first**\n\n- Read the error message carefully — it usually includes a line number, a stack trace, and a description of what went wrong.\n- Search the message: copy the most specific part of the error (not the whole stack trace) into Google. The format `<tool> <error message>` works well, e.g. `pgcli error column c.relhasoids does not exist`.\n- Check the official documentation of the tool you're using.\n- Use Ctrl+F in this FAQ and in Slack channel pinned messages.\n- Restart the process / container / shell / VM and try once more — many transient errors resolve this way.\n- If you suspect the install is broken, uninstall first, then reinstall. Reinstalling on top of a broken install rarely helps.\n\n**Asking for help in Slack / forums**\n\nWhen the troubleshooting steps don't help and you need another pair of eyes, include enough info that someone can actually help without going back and forth:\n\n- Operating system and version (e.g. Windows 11 + WSL Ubuntu 24.04, Mac M2, Linux Ubuntu 22.04).\n- Which lesson / video you're following, and which command failed.\n- The exact command and the exact error — paste both as text inside triple-backtick code blocks. Don't paste screenshots of text.\n- What you've already tried. If you skip this, helpers' first suggestions will be the things you already tried.\n- Stay in one thread. Reply to your own question; don't open a new post for a follow-up.\n\nIf the same problem recurs, post in the same thread with what changed in your environment since last time.\n\n**Help others by contributing back**\n\nIf your problem isn't yet covered in this FAQ, consider [opening a PR](https://github.com/DataTalksClub/faq) so the next student doesn't have to debug it from scratch."}, {'id': '29ef71cc59', 'course': 'machine-learning-zoomcamp', 'section': 'Miscellaneous', 'question': 'Is use of libraries like [fast.ai](http://fast.ai/) or Huggingface allowed in the capstone and competition, or are they considered to be "too much help"?', 'answer': 'Yes, it’s allowed.'}, {'id': '5f072b1cc7', 'course': 'data-engineering-zoomcamp', 'section': 'Module 3: Data Warehousing', 'question': 'Homework: Uploading files to GCS via GUI', 'answer': "This can help avoid schema issues in the homework. Download files locally and use the 'upload files' button in GCS at the desired path ...

# %%
assistant.rag('I just discovered the course. Can I join now?')
# Out:
# 'Yes, you can still join the course. However, please note that if you want to receive a certificate, you must submit your project while submissions are still being accepted.'
